# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Define the path to the uploaded file
file_path1 = '/content/drive/MyDrive/WVUResearch/iNTD132249.xls'


# Read the file as HTML
df0 = pd.read_html(file_path1,header=0)[0]

df0
# Out:
#          No.  Year SubRecipientCode Legacy Subrecipient ID  \
# 0          1  2018       0R01-00288               0R01-024
# 1          2  2018       0R01-00288               0R01-024
# 2          3  2018       0R01-00291               0R01-042
# 3          4  2018       0R01-00291               0R01-042
# 4          5  2018       0R01-00304               0R01-043
# ...      ...   ...              ...                    ...
# 17852  17853  2022       9R05-90999               9R05-001
# 17853  17854  2022       9R06-99434                    NaN
# 17854  17855  2022       9R06-99434                    NaN
# 17855  17856  2022       9R08-91045               9R08-001
# 17856  17857  2022       9R08-91045               9R08-001
#
#                                         SubRecipientName         City State  \
# 0                                         City of Moscow       Moscow    ID
# 1                                         City of Moscow       Moscow    ID
# 2                            Northwestern Stagelines Inc      Spokane    WA
# 3                            Northwestern Stagelines Inc      Spokane    WA
# 4                                      Salt Lake Express      Rexburg    ID
# ...                                                  ...          ...   ...
# 17852  Government of Guam-Guam Regional Transit Autho...  Upper Tumon    GU
# 17853    American Samoa Government Dept. of Public Works    Pago Pago    AS
# 17854    American Samoa Government Dept. of Public Works    Pago Pago    AS
# 17855                                               COTA       Saipan    MP
# 17856                                               COTA       Saipan    MP
#
#       Mode Basic Information - Subrecipient Reporter Type  \
# 0      All                                 Rural Reporter
# 1       VP                                            NaN
# 2      All                                 Rural Reporter
# 3       MB                                            NaN
# 4      All                                 Rural Reporter
# ...    ...                                            ...
# 17852   MB                                            NaN
# 17853  All                                 Rural Reporter
# 17854   DR                                            NaN
# 17855  All                                 Rural Reporter
# 17856   DR                                            NaN
#
#       Total Operating Expense  Total Active Revenue Vehicles  \
# 0                      $7,413                            4.0
# 1                      $7,413                            4.0
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
# ...                       ...                            ...
# 17852              $1,034,868                           11.0
# 17853              $1,005,200                           10.0
# 17854              $1,005,200                           10.0
# 17855              $1,710,908                           11.0
# 17856              $1,710,908                           11.0
#
#        Annual Vehicle Revenue Miles  Annual Vehicle Revenue Hours  \
# 0                           15308.0                         328.0
# 1                           15308.0                         328.0
# 2                          219000.0                           NaN
# 3                          219000.0                           NaN
# 4                         1773656.0                           NaN
# ...                             ...                           ...
# 17852                      241879.0                       16183.0
# 17853                      196729.0                       22566.0
# 17854                      196729.0                       22566.0
# 17855                      327650.0                       13820.0
# 17856                      327650.0                       13820.0
#
#        Total Unlinked Passenger Trips  Average Age of Fleet (in years)
# 0                              4023.0                             4.75
# 1                              4023.0                             4.75
# 2                              9605.0                              NaN
# 3                              9605.0                              NaN
# 4                             77135.0                              NaN
# ...                               ...                              ...
# 17852                         13197.0                             7.00
# 17853                         32229.0                             6.60
# 17854                         32229.0                             6.60
# 17855                         39031.0                             5.00
# 17856                         39031.0                             5.00
#
# [17857 rows x 15 columns]

# %%
#Let's get only the required columns
# Inputs: 'Total Operating Expense','Total Active Revenue Vehicles'
# Outputs: 'Annual Vehicle Revenue Miles','Total Unlinked Passenger Trips'
df=df0[['Year','SubRecipientCode', 'City','State','Mode', 'Basic Information - Subrecipient Reporter Type', 'Total Operating Expense','Total Active Revenue Vehicles','Annual Vehicle Revenue Miles','Total Unlinked Passenger Trips']]
df
# Out:
#        Year SubRecipientCode         City State Mode  \
# 0      2018       0R01-00288       Moscow    ID  All
# 1      2018       0R01-00288       Moscow    ID   VP
# 2      2018       0R01-00291      Spokane    WA  All
# 3      2018       0R01-00291      Spokane    WA   MB
# 4      2018       0R01-00304      Rexburg    ID  All
# ...     ...              ...          ...   ...  ...
# 17852  2022       9R05-90999  Upper Tumon    GU   MB
# 17853  2022       9R06-99434    Pago Pago    AS  All
# 17854  2022       9R06-99434    Pago Pago    AS   DR
# 17855  2022       9R08-91045       Saipan    MP  All
# 17856  2022       9R08-91045       Saipan    MP   DR
#
#       Basic Information - Subrecipient Reporter Type Total Operating Expense  \
# 0                                     Rural Reporter                  $7,413
# 1                                                NaN                  $7,413
# 2                                     Rural Reporter                     NaN
# 3                                                NaN                     NaN
# 4                                     Rural Reporter                     NaN
# ...                                              ...                     ...
# 17852                                            NaN              $1,034,868
# 17853                                 Rural Reporter              $1,005,200
# 17854                                            NaN              $1,005,200
# 17855                                 Rural Reporter              $1,710,908
# 17856                                            NaN              $1,710,908
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 0                                4.0                       15308.0
# 1                                4.0                       15308.0
# 2                                NaN                      219000.0
# 3                                NaN                      219000.0
# 4                                NaN                     1773656.0
# ...                              ...                           ...
# 17852                           11.0                      241879.0
# 17853                           10.0                      196729.0
# 17854                           10.0                      196729.0
# 17855                           11.0                      327650.0
# 17856                           11.0                      327650.0
#
#        Total Unlinked Passenger Trips
# 0                              4023.0
# 1                              4023.0
# 2                              9605.0
# 3                              9605.0
# 4                             77135.0
# ...                               ...
# 17852                         13197.0
# 17853                         32229.0
# 17854                         32229.0
# 17855                         39031.0
# 17856                         39031.0
#
# [17857 rows x 10 columns]

# %%
print(df['Basic Information - Subrecipient Reporter Type'].unique())
# Out:
# ['Rural Reporter' nan 'Reduced Asset Reporter']

# %%
rural_df = df[df['Basic Information - Subrecipient Reporter Type'] == 'Rural Reporter']
print(rural_df.shape)
rural_df
# Out:
# (6308, 10)
#        Year SubRecipientCode         City State Mode  \
# 0      2018       0R01-00288       Moscow    ID  All
# 2      2018       0R01-00291      Spokane    WA  All
# 4      2018       0R01-00304      Rexburg    ID  All
# 6      2018       0R01-00306      Marsing    ID  All
# 8      2018       0R01-00311      Ketchum    ID  All
# ...     ...              ...          ...   ...  ...
# 17846  2022       9R04-91113    Yerington    NV  All
# 17848  2022       9R04-99430      Pahrump    NV  All
# 17850  2022       9R05-90999  Upper Tumon    GU  All
# 17853  2022       9R06-99434    Pago Pago    AS  All
# 17855  2022       9R08-91045       Saipan    MP  All
#
#       Basic Information - Subrecipient Reporter Type Total Operating Expense  \
# 0                                     Rural Reporter                  $7,413
# 2                                     Rural Reporter                     NaN
# 4                                     Rural Reporter                     NaN
# 6                                     Rural Reporter                  $1,523
# 8                                     Rural Reporter              $2,722,290
# ...                                              ...                     ...
# 17846                                 Rural Reporter                $192,122
# 17848                                 Rural Reporter                $566,863
# 17850                                 Rural Reporter              $2,026,980
# 17853                                 Rural Reporter              $1,005,200
# 17855                                 Rural Reporter              $1,710,908
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 0                                4.0                       15308.0
# 2                                NaN                      219000.0
# 4                                NaN                     1773656.0
# 6                                2.0                         779.0
# 8                               35.0                      851065.0
# ...                              ...                           ...
# 17846                           12.0                       56906.0
# 17848                           13.0                      258508.0
# 17850                           29.0                      445097.0
# 17853                           10.0                      196729.0
# 17855                           11.0                      327650.0
#
#        Total Unlinked Passenger Trips
# 0                              4023.0
# 2                              9605.0
# 4                             77135.0
# 6                               174.0
# 8                            536583.0
# ...                               ...
# 17846                          5177.0
# 17848                         30292.0
# 17850                         24554.0
# 17853                         32229.0
# 17855                         39031.0
#
# [6308 rows x 10 columns]

# %%
# rural_df.to_csv('/content/drive/MyDrive/WVUResearch/rural_data.csv', index=False)

# %%
rural_df['Mode'].unique()
# Out:
# array(['All'], dtype=object)

# %%
len(rural_df['State'].unique())
# Out:
# 52

# %%
len(rural_df['SubRecipientCode'].unique())
# Out:
# 1367

# %%
# Count the number of NaN values in each specified column
na_counts = rural_df[rural_df.columns].isna().sum()

# Display the counts of NaN values
na_counts
# Out:
# Year                                                0
# SubRecipientCode                                    0
# City                                               28
# State                                               0
# Mode                                                0
# Basic Information - Subrecipient Reporter Type      0
# Total Operating Expense                           486
# Total Active Revenue Vehicles                     496
# Annual Vehicle Revenue Miles                       36
# Total Unlinked Passenger Trips                     35
# dtype: int64

# %%
#Let's remove all naN values
rural_df=rural_df.dropna()
rural_df
# Out:
#        Year SubRecipientCode         City State Mode  \
# 0      2018       0R01-00288       Moscow    ID  All
# 6      2018       0R01-00306      Marsing    ID  All
# 8      2018       0R01-00311      Ketchum    ID  All
# 12     2018       0R01-00341     Ponderay    ID  All
# 15     2018       0R01-00342   St. Maries    ID  All
# ...     ...              ...          ...   ...  ...
# 17846  2022       9R04-91113    Yerington    NV  All
# 17848  2022       9R04-99430      Pahrump    NV  All
# 17850  2022       9R05-90999  Upper Tumon    GU  All
# 17853  2022       9R06-99434    Pago Pago    AS  All
# 17855  2022       9R08-91045       Saipan    MP  All
#
#       Basic Information - Subrecipient Reporter Type Total Operating Expense  \
# 0                                     Rural Reporter                  $7,413
# 6                                     Rural Reporter                  $1,523
# 8                                     Rural Reporter              $2,722,290
# 12                                    Rural Reporter                $516,231
# 15                                    Rural Reporter                $242,093
# ...                                              ...                     ...
# 17846                                 Rural Reporter                $192,122
# 17848                                 Rural Reporter                $566,863
# 17850                                 Rural Reporter              $2,026,980
# 17853                                 Rural Reporter              $1,005,200
# 17855                                 Rural Reporter              $1,710,908
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 0                                4.0                       15308.0
# 6                                2.0                         779.0
# 8                               35.0                      851065.0
# 12                               8.0                      167051.0
# 15                              13.0                       92075.0
# ...                              ...                           ...
# 17846                           12.0                       56906.0
# 17848                           13.0                      258508.0
# 17850                           29.0                      445097.0
# 17853                           10.0                      196729.0
# 17855                           11.0                      327650.0
#
#        Total Unlinked Passenger Trips
# 0                              4023.0
# 6                               174.0
# 8                            536583.0
# 12                            69822.0
# 15                            25449.0
# ...                               ...
# 17846                          5177.0
# 17848                         30292.0
# 17850                         24554.0
# 17853                         32229.0
# 17855                         39031.0
#
# [5781 rows x 10 columns]

# %%
# Group by SubRecipientCode and count the number of unique years for each agency
agency_years_count = rural_df.groupby('SubRecipientCode')['Year'].nunique()

# Filter agencies that have data for all years from 2018 to 2022 (i.e., 5 years)
agencies_with_full_data = agency_years_count[agency_years_count == 5].index

# Filter the main DataFrame to include only these agencies
df = rural_df[rural_df['SubRecipientCode'].isin(agencies_with_full_data)]
# Function to clean dollar values and convert them to float
def clean_currency(value):
    # Remove dollar sign and commas, then convert to float
    return float(value.replace('$', '').replace(',', ''))

# Apply the function to the 'Total Operating Expense' column
df['Total Operating Expense'] = df['Total Operating Expense'].apply(clean_currency)
# Display the filtered DataFrame
df
# Out:
# <ipython-input-33-6fec763e77d9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Operating Expense'] = df['Total Operating Expense'].apply(clean_currency)
#        Year SubRecipientCode         City State Mode  \
# 8      2018       0R01-00311      Ketchum    ID  All
# 12     2018       0R01-00341     Ponderay    ID  All
# 17     2018       0R01-00347     Lewiston    ID  All
# 20     2018       0R01-00357   Twin Falls    ID  All
# 24     2018       0R01-00403       Salmon    ID  All
# ...     ...              ...          ...   ...  ...
# 17842  2022       9R04-91107     Laughlin    NV  All
# 17846  2022       9R04-91113    Yerington    NV  All
# 17848  2022       9R04-99430      Pahrump    NV  All
# 17850  2022       9R05-90999  Upper Tumon    GU  All
# 17853  2022       9R06-99434    Pago Pago    AS  All
#
#       Basic Information - Subrecipient Reporter Type  Total Operating Expense  \
# 8                                     Rural Reporter                2722290.0
# 12                                    Rural Reporter                 516231.0
# 17                                    Rural Reporter                 590539.0
# 20                                    Rural Reporter                 545266.0
# 24                                    Rural Reporter                 156627.0
# ...                                              ...                      ...
# 17842                                 Rural Reporter                1115748.0
# 17846                                 Rural Reporter                 192122.0
# 17848                                 Rural Reporter                 566863.0
# 17850                                 Rural Reporter                2026980.0
# 17853                                 Rural Reporter                1005200.0
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 8                               35.0                      851065.0
# 12                               8.0                      167051.0
# 17                              10.0                       84099.0
# 20                              12.0                       87298.0
# 24                               4.0                       32097.0
# ...                              ...                           ...
# 17842                           15.0                      241989.0
# 17846                           12.0                       56906.0
# 17848                           13.0                      258508.0
# 17850                           29.0                      445097.0
# 17853                           10.0                      196729.0
#
#        Total Unlinked Passenger Trips
# 8                            536583.0
# 12                            69822.0
# 17                           161322.0
# 20                            19938.0
# 24                            16747.0
# ...                               ...
# 17842                         77434.0
# 17846                          5177.0
# 17848                         30292.0
# 17850                         24554.0
# 17853                         32229.0
#
# [5295 rows x 10 columns]

# %%
len(df['SubRecipientCode'].unique()), len(df['State'].unique())
# Out:
# (1059, 51)

# %%
# Counting unique states and agencies for each year
unique_counts = df.groupby('Year').agg(
    Unique_States=('State', 'nunique'),
    Unique_Agencies=('SubRecipientCode', 'nunique')
)

# Display the result
unique_counts
# Out:
#       Unique_States  Unique_Agencies
# Year
# 2018             51             1059
# 2019             51             1059
# 2020             51             1059
# 2021             51             1059
# 2022             51             1059

# %%
# Grouping by 'State' and 'Year' to count the number of agencies
agencies_per_state_year = df.groupby(['State', 'Year'])['SubRecipientCode'].nunique().reset_index()

# Renaming the columns for clarity
agencies_per_state_year.columns = ['State', 'Year', 'Number of Agencies']

# Display the result
agencies_per_state_year
# Out:
#     State  Year  Number of Agencies
# 0      AK  2018                  10
# 1      AK  2019                  10
# 2      AK  2020                  10
# 3      AK  2021                  10
# 4      AK  2022                  10
# ..    ...   ...                 ...
# 250    WY  2018                  16
# 251    WY  2019                  16
# 252    WY  2020                  16
# 253    WY  2021                  16
# 254    WY  2022                  16
#
# [255 rows x 3 columns]

# %%
# Checking for states where the number of agencies varies over the years
states_with_changes = agencies_per_state_year.groupby('State')['Number of Agencies'].nunique().reset_index()

# Filtering states where the number of unique agency counts is greater than 1
states_with_changes = states_with_changes[states_with_changes['Number of Agencies'] > 1]

# Display the states where the number of agencies changed
print(states_with_changes)
# Out:
#    State  Number of Agencies
# 8     FL                   2
# 23    MN                   2
# 24    MO                   2
# 29    NE                   2
# 41    SD                   2
# 43    TX                   2
# 45    VA                   2
# 48    WI                   2

# %%
# Filter the original data for states with changes in the number of agencies
states_to_check = states_with_changes['State'].unique()

# Filter the data for only those states with discrepancies
discrepancies_df = df[df['State'].isin(states_to_check)]

# Group by SubRecipientCode and check if the agencies are linked to multiple states
agency_state_discrepancies = discrepancies_df.groupby('SubRecipientCode')['State'].nunique().reset_index()

# Filter for agencies appearing in more than one state
agency_state_discrepancies = agency_state_discrepancies[agency_state_discrepancies['State'] > 1]

# Merge back to get full details of these agencies
discrepancies_details = discrepancies_df[discrepancies_df['SubRecipientCode'].isin(agency_state_discrepancies['SubRecipientCode'])]

# Display the details
discrepancies_details
# Out:
#        Year SubRecipientCode                 City State Mode  \
# 582    2018       3R06-30147  Chincoteague Island    VA  All
# 1709   2018       5R06-50478            Marinette    MN  All
# 2194   2018       7R03-70091        Fredericktown    TX  All
# 2318   2018       7R04-70216            Creighton    NE  All
# 3870   2019       3R06-30147  Chincoteague Island    VA  All
# 5224   2019       5R06-50478            Marinette    MN  All
# 5909   2019       7R03-70091        Fredericktown    TX  All
# 6033   2019       7R04-70216            Creighton    NE  All
# 7628   2020       3R06-30147              Panacea    VA  All
# 8963   2020       5R06-50478            Marinette    WI  All
# 9679   2020       7R03-70091        Fredericktown    MO  All
# 9799   2020       7R04-70216              Yankton    NE  All
# 11408  2021       3R06-30147              Panacea    VA  All
# 12743  2021       5R06-50478            Marinette    WI  All
# 13437  2021       7R03-70091        Fredericktown    MO  All
# 13560  2021       7R04-70216              Yankton    NE  All
# 15123  2022       3R06-30147              Panacea    FL  All
# 16417  2022       5R06-50478            Marinette    WI  All
# 17076  2022       7R03-70091        Fredericktown    MO  All
# 17196  2022       7R04-70216              Yankton    SD  All
#
#       Basic Information - Subrecipient Reporter Type  Total Operating Expense  \
# 582                                   Rural Reporter                  90603.0
# 1709                                  Rural Reporter                 447818.0
# 2194                                  Rural Reporter                7882301.0
# 2318                                  Rural Reporter                 135882.0
# 3870                                  Rural Reporter                  90514.0
# 5224                                  Rural Reporter                 451762.0
# 5909                                  Rural Reporter                7083590.0
# 6033                                  Rural Reporter                 157302.0
# 7628                                  Rural Reporter                  78386.0
# 8963                                  Rural Reporter                 394136.0
# 9679                                  Rural Reporter                6505959.0
# 9799                                  Rural Reporter                 201846.0
# 11408                                 Rural Reporter                  83463.0
# 12743                                 Rural Reporter                 474223.0
# 13437                                 Rural Reporter                6088570.0
# 13560                                 Rural Reporter                 293478.0
# 15123                                 Rural Reporter                  73474.0
# 16417                                 Rural Reporter                 470851.0
# 17076                                 Rural Reporter                6665314.0
# 17196                                 Rural Reporter                 392419.0
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 582                              4.0                       11873.0
# 1709                             5.0                      145981.0
# 2194                           179.0                     3628970.0
# 2318                             5.0                       89072.0
# 3870                             4.0                       17178.0
# 5224                             5.0                      149738.0
# 5909                           180.0                     3629861.0
# 6033                             6.0                      104019.0
# 7628                             4.0                       13998.0
# 8963                             5.0                      123589.0
# 9679                           191.0                     2888238.0
# 9799                             6.0                      101538.0
# 11408                            4.0                        9930.0
# 12743                            5.0                      139745.0
# 13437                          188.0                     2764013.0
# 13560                            6.0                      116144.0
# 15123                            4.0                        6777.0
# 16417                            5.0                      124040.0
# 17076                          181.0                     2517446.0
# 17196                            6.0                      143470.0
#
#        Total Unlinked Passenger Trips
# 582                           14728.0
# 1709                          37236.0
# 2194                         314096.0
# 2318                           5186.0
# 3870                          12353.0
# 5224                          36602.0
# 5909                         313392.0
# 6033                           4695.0
# 7628                          11562.0
# 8963                          29789.0
# 9679                         335111.0
# 9799                           4701.0
# 11408                          2825.0
# 12743                         29079.0
# 13437                        278493.0
# 13560                          4703.0
# 15123                          3001.0
# 16417                         33779.0
# 17076                        263182.0
# 17196                          6312.0

# %%
# Define the mapping of states to regions
regions = {
    'New England': ['CT', 'ME', 'MA', 'NH', 'RI', 'VT'],
    'Middle Atlantic': ['NJ', 'NY', 'PA'],
    'East North Central': ['IL', 'IN', 'MI', 'OH', 'WI'],
    'West North Central': ['IA', 'KS', 'MN', 'MO', 'NE', 'ND', 'SD'],
    'South Atlantic': ['DE', 'FL', 'GA', 'MD', 'NC', 'SC', 'VA', 'WV', 'DC'],
    'East South Central': ['AL', 'KY', 'MS', 'TN'],
    'West South Central': ['AR', 'LA', 'OK', 'TX'],
    'Mountain': ['AZ', 'CO', 'ID', 'MT', 'NV', 'NM', 'UT', 'WY'],
    'Pacific': ['AK', 'CA', 'HI', 'OR', 'WA', 'GU', 'AS', 'PR']
}

# Flatten the dictionary into a state-to-region mapping
state_to_region = {state: region for region, states in regions.items() for state in states}

# Ensure the 'State' column is in your DataFrame (if not, you might need to derive it)
# Add a new 'Region' column by mapping the 'State' column
df['Region'] = df['State'].map(state_to_region)
df
# Out:
# <ipython-input-39-2b04dff3ce0c>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region'] = df['State'].map(state_to_region)
#        Year SubRecipientCode         City State Mode  \
# 8      2018       0R01-00311      Ketchum    ID  All
# 12     2018       0R01-00341     Ponderay    ID  All
# 17     2018       0R01-00347     Lewiston    ID  All
# 20     2018       0R01-00357   Twin Falls    ID  All
# 24     2018       0R01-00403       Salmon    ID  All
# ...     ...              ...          ...   ...  ...
# 17842  2022       9R04-91107     Laughlin    NV  All
# 17846  2022       9R04-91113    Yerington    NV  All
# 17848  2022       9R04-99430      Pahrump    NV  All
# 17850  2022       9R05-90999  Upper Tumon    GU  All
# 17853  2022       9R06-99434    Pago Pago    AS  All
#
#       Basic Information - Subrecipient Reporter Type  Total Operating Expense  \
# 8                                     Rural Reporter                2722290.0
# 12                                    Rural Reporter                 516231.0
# 17                                    Rural Reporter                 590539.0
# 20                                    Rural Reporter                 545266.0
# 24                                    Rural Reporter                 156627.0
# ...                                              ...                      ...
# 17842                                 Rural Reporter                1115748.0
# 17846                                 Rural Reporter                 192122.0
# 17848                                 Rural Reporter                 566863.0
# 17850                                 Rural Reporter                2026980.0
# 17853                                 Rural Reporter                1005200.0
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 8                               35.0                      851065.0
# 12                               8.0                      167051.0
# 17                              10.0                       84099.0
# 20                              12.0                       87298.0
# 24                               4.0                       32097.0
# ...                              ...                           ...
# 17842                           15.0                      241989.0
# 17846                           12.0                       56906.0
# 17848                           13.0                      258508.0
# 17850                           29.0                      445097.0
# 17853                           10.0                      196729.0
#
#        Total Unlinked Passenger Trips    Region
# 8                            536583.0  Mountain
# 12                            69822.0  Mountain
# 17                           161322.0  Mountain
# 20                            19938.0  Mountain
# 24                            16747.0  Mountain
# ...                               ...       ...
# 17842                         77434.0  Mountain
# 17846                          5177.0  Mountain
# 17848                         30292.0  Mountain
# 17850                         24554.0   Pacific
# 17853                         32229.0   Pacific
#
# [5295 rows x 11 columns]

# %%
agency_count_by_region = df.groupby('Region').size().reset_index(name='Agency Count')

agency_count_by_region
# Out:
#                Region  Agency Count
# 0  East North Central          1073
# 1  East South Central           320
# 2     Middle Atlantic           255
# 3            Mountain           615
# 4         New England           130
# 5             Pacific           570
# 6      South Atlantic           830
# 7  West North Central          1075
# 8  West South Central           427

# %%
85 * 5
# Out:
# 425

# %%
regions2 = {
    'New England': ['CT', 'ME', 'MA', 'NH', 'RI', 'VT'],
    'Mid-Atlantic': ['NJ', 'NY', 'PA'],
    'East North Central': ['IL', 'IN', 'MI', 'OH', 'WI'],
    'West North Central': ['IA', 'KS', 'MN', 'MO', 'NE', 'ND', 'SD'],
    'South Atlantic': ['DE', 'FL', 'GA', 'MD', 'NC', 'SC', 'VA', 'WV', 'DC'],
    'South Central': ['AL', 'KY', 'MS', 'TN', 'AR', 'LA', 'OK', 'TX'],
    'Mountain': ['AZ', 'CO', 'ID', 'MT', 'NV', 'NM', 'UT', 'WY'],
    'Pacific': ['AK', 'CA', 'HI', 'OR', 'WA'],
    'Territories': ['GU', 'AS', 'PR']
}

# Flatten the dictionary into a state-to-region mapping
state_to_region = {state: region for region, states in regions2.items() for state in states}

# Ensure the 'State' column is in your DataFrame (if not, you might need to derive it)
# Add a new 'Region' column by mapping the 'State' column
df['Region2'] = df['State'].map(state_to_region)
df
# Out:
# <ipython-input-54-379577726caf>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region2'] = df['State'].map(state_to_region)
#        Year SubRecipientCode         City State Mode  \
# 8      2018       0R01-00311      Ketchum    ID  All
# 12     2018       0R01-00341     Ponderay    ID  All
# 17     2018       0R01-00347     Lewiston    ID  All
# 20     2018       0R01-00357   Twin Falls    ID  All
# 24     2018       0R01-00403       Salmon    ID  All
# ...     ...              ...          ...   ...  ...
# 17842  2022       9R04-91107     Laughlin    NV  All
# 17846  2022       9R04-91113    Yerington    NV  All
# 17848  2022       9R04-99430      Pahrump    NV  All
# 17850  2022       9R05-90999  Upper Tumon    GU  All
# 17853  2022       9R06-99434    Pago Pago    AS  All
#
#       Basic Information - Subrecipient Reporter Type  Total Operating Expense  \
# 8                                     Rural Reporter                2722290.0
# 12                                    Rural Reporter                 516231.0
# 17                                    Rural Reporter                 590539.0
# 20                                    Rural Reporter                 545266.0
# 24                                    Rural Reporter                 156627.0
# ...                                              ...                      ...
# 17842                                 Rural Reporter                1115748.0
# 17846                                 Rural Reporter                 192122.0
# 17848                                 Rural Reporter                 566863.0
# 17850                                 Rural Reporter                2026980.0
# 17853                                 Rural Reporter                1005200.0
#
#        Total Active Revenue Vehicles  Annual Vehicle Revenue Miles  \
# 8                               35.0                      851065.0
# 12                               8.0                      167051.0
# 17                              10.0                       84099.0
# 20                              12.0                       87298.0
# 24                               4.0                       32097.0
# ...                              ...                           ...
# 17842                           15.0                      241989.0
# 17846                           12.0                       56906.0
# 17848                           13.0                      258508.0
# 17850                           29.0                      445097.0
# 17853                           10.0                      196729.0
#
#        Total Unlinked Passenger Trips    Region      Region2
# 8                            536583.0  Mountain     Mountain
# 12                            69822.0  Mountain     Mountain
# 17                           161322.0  Mountain     Mountain
# 20                            19938.0  Mountain     Mountain
# 24                            16747.0  Mountain     Mountain
# ...                               ...       ...          ...
# 17842                         77434.0   Pacific     Mountain
# 17846                          5177.0   Pacific     Mountain
# 17848                         30292.0   Pacific     Mountain
# 17850                         24554.0   Pacific  Territories
# 17853                         32229.0   Pacific  Territories
#
# [5295 rows x 12 columns]

# %%
agency_count_by_region = df.groupby('Region2').size().reset_index(name='Agency Count')

agency_count_by_region
# Out:
#               Region2  Agency Count
# 0  East North Central          1073
# 1        Mid-Atlantic           255
# 2            Mountain           615
# 3         New England           130
# 4             Pacific           540
# 5      South Atlantic           830
# 6       South Central           747
# 7         Territories            30
# 8  West North Central          1075

# %%
agency_count_by_state = df.groupby('State').size().reset_index(name='State Count')
agency_count_by_state
# Out:
#    State  State Count
# 0     AK           50
# 1     AL          100
# 2     AR           40
# 3     AS            5
# 4     AZ           65
# 5     CA          240
# 6     CO          145
# 7     CT           10
# 8     FL           91
# 9     GA          290
# 10    GU            5
# 11    HI           10
# 12    IA           95
# 13    ID           30
# 14    IL          190
# 15    IN          190
# 16    KS          360
# 17    KY          100
# 18    LA          155
# 19    MA           15
# 20    MD           25
# 21    ME           45
# 22    MI          300
# 23    MN          127
# 24    MO          103
# 25    MS           80
# 26    MT          155
# 27    NC          265
# 28    ND          105
# 29    NE          229
# 30    NH           25
# 31    NJ           20
# 32    NM           65
# 33    NV           60
# 34    NY          190
# 35    OH          165
# 36    OK          100
# 37    OR          120
# 38    PA           45
# 39    PR           20
# 40    SC           40
# 41    SD           56
# 42    TN           40
# 43    TX          132
# 44    UT           15
# 45    VA           74
# 46    VT           35
# 47    WA          120
# 48    WI          228
# 49    WV           45
# 50    WY           80
